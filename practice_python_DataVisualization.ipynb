# %%
import pandas as pd
import os
os.chdir(r'E:\Courses\Python Basics to Advanced')

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Car_sales.csv')

# %%
df.describe()
# Out:
#        Sales in thousands  4-year resale value  Price in thousands  \
# count          157.000000           157.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            10.045282           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            12.545000           18.017500
# 50%             29.450000            17.710000           22.799000
# 75%             67.956000            18.140000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  157.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.518297    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
#Based on the end goal - We decide to create the visuals

# %%
#Univariate Analysis 
Single Variable 
Categorical Variable 
Numerical Variable

# %%
sns.histplot(df['4-year resale value'])
# Out:
# <Axes: xlabel='4-year resale value', ylabel='Count'>

# %%
sns.boxplot(df['4-year resale value'])
# Out:
# <Axes: ylabel='4-year resale value'>

# %%
sns.countplot(df['Vehicle type'])
# Out:
# <Axes: xlabel='count', ylabel='Vehicle type'>

# %%
sns.countplot(data=df, y='Vehicle type')
# Out:
# <Axes: xlabel='count', ylabel='Vehicle type'>

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
#Bivariate Analysis

category-Category 
Category-Numerical 
Numerical-Numerical

# %%
df.groupby(['Manufacturer','Vehicle type']).size()
# Out:
# Manufacturer   Vehicle type
# Acura          Passenger       4
# Audi           Passenger       3
# BMW            Passenger       3
# Buick          Passenger       4
# Cadillac       Car             1
#                Passenger       4
# Chevrolet      Passenger       9
# Chrysler       Car             1
#                Passenger       6
# Dodge          Car             6
#                Passenger       5
# Ford           Car             5
#                Passenger       6
# Honda          Car             3
#                Passenger       2
# Hyundai        Passenger       3
# Infiniti       Passenger       1
# Jaguar         Passenger       1
# Jeep           Car             3
# Lexus          Car             2
#                Passenger       4
# Lincoln        Car             1
#                Passenger       2
# Mercedes-Benz  Car             1
#                Passenger       8
# Mercury        Car             2
#                Passenger       4
# ...

# %%
#Catergorical and Numerical 
    #Bar Chart 
    #Pie Chart

# %%
Vehicle type

# %%
sns.barplot(data = df)
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
sns.countplot(data = df , y = 'Manufacturer',hue='Vehicle type')
# Out:
# <Axes: xlabel='count', ylabel='Manufacturer'>

# %%
sns.barplot(data=df, x='Vehicle type', y='4-year resale value',estimator='mean')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
sns.stripplot(data=df, x='Vehicle type', y='4-year resale value')
# Out:
# <Axes: xlabel='Vehicle type', ylabel='4-year resale value'>

# %%
#Numerical and Numrical 

sns.lmplot

sns.regplot

sns.scatterplot

sns.jointplot

sns.pairplot

# %%
df
# Out:
#       Manufacturer              Model  Sales in thousands  \
# 0       Mitsubishi  3000GT                          0.110
# 1            Dodge  Viper                           0.916
# 2    Mercedes-Benz  CL500                           0.954
# 3       Oldsmobile  Cutlass                         1.112
# 4          Porsche  Carrera Coupe                   1.280
# ..             ...                ...                 ...
# 152          Honda  Accord                        230.902
# 153           Ford  Taurus                        245.815
# 154         Toyota  Camry                         247.994
# 155           Ford  Explorer                      276.747
# 156           Ford  F-Series                      540.561
#
#      4-year resale value Vehicle type  Price in thousands  Engine size  \
# 0              20.940000    Passenger              25.450          3.0
# 1              58.470000    Passenger              69.725          8.0
# ...

# %%
sns.scatterplot(data = df, x='Fuel capacity',y='Fuel efficiency',hue='Vehicle type')
# Out:
# <Axes: xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.regplot(data=df,x='Fuel capacity',y='Fuel efficiency',fit_reg=False,color='red')
# Out:
# <Axes: xlabel='Fuel capacity', ylabel='Fuel efficiency'>

# %%
sns.lmplot(data=df,x='Fuel capacity',y='Fuel efficiency',fit_reg=False,hue='Manufacturer',col='Vehicle type')

# %%
sns.jointplot(data=df, x='Fuel capacity', y='Fuel efficiency',hue='Vehicle type')

# %%
plt.scatter(df['Fuel capacity'], df['Fuel efficiency'])

# %%
sns.pairplot(df[['Horsepower', 'Wheelbase', 'Curb weight', 'Fuel capacity', 'Fuel efficiency', 'Vehicle type']],hue='Vehicle type')

# %%
sns.heatmap(df[['Horsepower', 'Wheelbase', 'Curb weight', 'Fuel capacity', 'Fuel efficiency']].corr(),annot=True)
# Out:
# <Axes: >
